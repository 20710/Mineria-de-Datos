# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'educacion_00.1.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
# C:\Users\Gabriel\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    cve_entidad              desc_entidad  cve_municipio  \
# 0            0  Estados Unidos Mexicanos              0
# 1            0  Estados Unidos Mexicanos              0
# 2            0  Estados Unidos Mexicanos              0
# 3            0  Estados Unidos Mexicanos              0
# 4            0  Estados Unidos Mexicanos              0
#
#              desc_municipio  id_indicador  \
# 0  Estados Unidos Mexicanos    3108001001
# 1  Estados Unidos Mexicanos    3108001002
# 2  Estados Unidos Mexicanos    3108001003
# 3  Estados Unidos Mexicanos    6200240314
# 4  Estados Unidos Mexicanos    6200240365
#
#                                            indicador  1910  1921  1930  1940  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34926 entries, 0 to 34925
# Data columns (total 21 columns):
# cve_entidad       34926 non-null int64
# desc_entidad      34926 non-null object
# cve_municipio     34926 non-null int64
# desc_municipio    34926 non-null object
# id_indicador      34926 non-null int64
# indicador         34926 non-null object
# 1910              93 non-null float64
# 1921              96 non-null float64
# 1930              96 non-null float64
# 1940              96 non-null float64
# 1950              96 non-null float64
# 1960              96 non-null float64
# 1970              99 non-null float64
# 1980              96 non-null float64
# 1990              99 non-null float64
# 1995              99 non-null float64
# 2000              99 non-null float64
# 2005              99 non-null float64
# 2010              102 non-null float64
# 2015              34601 non-null object
# unidad_medida     34926 non-null object
# ...

# %%
df.shape
# Out:
# (34926, 21)

# %%
df.columns.values.tolist()
# Out:
# ['cve_entidad',
#  'desc_entidad',
#  'cve_municipio',
#  'desc_municipio',
#  'id_indicador',
#  'indicador',
#  '1910',
#  '1921',
#  '1930',
#  '1940',
#  '1950',
#  '1960',
#  '1970',
#  '1980',
#  '1990',
#  '1995',
#  '2000',
#  '2005',
#  '2010',
#  '2015',
#  'unidad_medida']

# %%
df.dtypes
# Out:
# cve_entidad         int64
# desc_entidad       object
# cve_municipio       int64
# desc_municipio     object
# id_indicador        int64
# indicador          object
# 1910              float64
# 1921              float64
# 1930              float64
# 1940              float64
# 1950              float64
# 1960              float64
# 1970              float64
# 1980              float64
# 1990              float64
# 1995              float64
# 2000              float64
# 2005              float64
# 2010              float64
# 2015               object
# unidad_medida      object
# dtype: object

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.describe()
# Out:
#         cve_entidad  cve_municipio  id_indicador       1910       1921  \
# count  34926.000000   34926.000000  3.492600e+04  93.000000  96.000000
# mean      19.211161     107.102932  6.196791e+09  67.572043  60.743750
# std        7.394582     132.165025  1.647084e+08  12.697735  16.493659
# min        0.000000       0.000000  3.108001e+09  28.700000  19.300000
# 25%       14.000000      22.000000  6.207019e+09  59.400000  50.700000
# 50%       20.000000      55.000000  6.207019e+09  68.900000  62.750000
# 75%       24.000000     125.000000  6.207019e+09  76.000000  76.100000
# max       32.000000     570.000000  6.207019e+09  92.100000  87.400000
#
#           1930       1940       1950       1960       1970       1980  \
# count  96.0000  96.000000  96.000000  96.000000  99.000000  96.000000
# mean   60.0500  50.490625  41.280208  33.709375  26.121818  17.441667
# std    16.0173  17.225575  14.716125  14.591902  11.299655   9.396737
# ...

# %%
df.cve_entidad.values
# Out:
# array([ 0,  0,  0, ..., 32, 32, 32], dtype=int64)

# %%
df['cve_entidad'].values
# Out:
# array([ 0,  0,  0, ..., 32, 32, 32], dtype=int64)

# %%
df.groupby('cve_entidad').agg(['count', 'size', 'nunique']).stack()
# Out:
#                      desc_entidad  cve_municipio  desc_municipio  \
# cve_entidad
# 0           count              17             17              17
#             size               17             17              17
#             nunique             1              1               1
# 1           count             171            171             171
#             size              171            171             171
#             nunique             1             12              12
# 2           count              87             87              87
#             size               87             87              87
#             nunique             1              6               6
# 3           count              87             87              87
#             size               87             87              87
#             nunique             1              6               6
# 4           count             171            171             171
# ...

# %%
df.groupby('cve_entidad').agg(['count', 'size', 'nunique'])
# Out:
#             desc_entidad               cve_municipio                \
#                    count  size nunique         count  size nunique
# cve_entidad
# 0                     17    17       1            17    17       1
# 1                    171   171       1           171   171      12
# 2                     87    87       1            87    87       6
# 3                     87    87       1            87    87       6
# 4                    171   171       1           171   171      12
# 5                    549   549       1           549   549      39
# 6                    157   157       1           157   157      11
# 7                   1669  1669       1          1669  1669     119
# 8                    940   940       1           940   940      68
# 9                    241   241       1           241   241      17
# 10                   563   563       1           563   563      40
# 11                   661   661       1           661   661      47
# ...

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#        cve_entidad desc_entidad  cve_municipio               desc_municipio  \
# 7318            13      Hidalgo             60             Tenango de Doria
# 25168           21       Puebla            206                     Zacapala
# 13491           18      Nayarit             15           Santiago Ixcuintla
# 17046           20       Oaxaca            196  San Juan Evangelista Analco
# 1390             7      Chiapas             10            Bejucal de Ocampo
#
#        id_indicador                                          indicador  1910  \
# 7318     6207019067  Porcentaje de la poblacin de 6 a 11 aos que ...   NaN
# 25168    6200240368  Porcentaje de la poblacin de 15 aos y ms co...   NaN
# 13491    6207019031  Porcentaje de poblacin de 15 aos y ms con e...   NaN
# 17046    6207019029  Porcentaje de la poblacin de 15 a 24 aos que...   NaN
# 1390     6207019029  Porcentaje de la poblacin de 15 a 24 aos que...   NaN
#
# ...

# %%
df.shape
# Out:
# (34926, 21)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#    cve_entidad              desc_entidad  cve_municipio  \
# 0            0  Estados Unidos Mexicanos              0
# 1            0  Estados Unidos Mexicanos              0
# 2            0  Estados Unidos Mexicanos              0
# 3            0  Estados Unidos Mexicanos              0
# 4            0  Estados Unidos Mexicanos              0
#
#              desc_municipio  id_indicador  \
# 0  Estados Unidos Mexicanos    3108001001
# 1  Estados Unidos Mexicanos    3108001002
# 2  Estados Unidos Mexicanos    3108001003
# 3  Estados Unidos Mexicanos    6200240314
# 4  Estados Unidos Mexicanos    6200240365
#
#                                            indicador  1910  1921  1930  1940  \
# 0                    Porcentaje de analfabetas total   NaN   NaN   NaN   NaN
# 1                  Porcentaje de analfabetas hombres   NaN   NaN   NaN   NaN
# 2                  Porcentaje de analfabetas mujeres   NaN   NaN   NaN   NaN
# ...

# %%
df_dropped = df.dropna(subset=['cve_entidad'])
df_dropped.head()
# Out:
#    cve_entidad              desc_entidad  cve_municipio  \
# 0            0  Estados Unidos Mexicanos              0
# 1            0  Estados Unidos Mexicanos              0
# 2            0  Estados Unidos Mexicanos              0
# 3            0  Estados Unidos Mexicanos              0
# 4            0  Estados Unidos Mexicanos              0
#
#              desc_municipio  id_indicador  \
# 0  Estados Unidos Mexicanos    3108001001
# 1  Estados Unidos Mexicanos    3108001002
# 2  Estados Unidos Mexicanos    3108001003
# 3  Estados Unidos Mexicanos    6200240314
# 4  Estados Unidos Mexicanos    6200240365
#
#                                            indicador  1910  1921  1930  1940  \
# 0                    Porcentaje de analfabetas total   NaN   NaN   NaN   NaN
# 1                  Porcentaje de analfabetas hombres   NaN   NaN   NaN   NaN
# 2                  Porcentaje de analfabetas mujeres   NaN   NaN   NaN   NaN
# ...

# %%
df_dropped['2010'].dtype
# Out:
# dtype('float64')

# %%
df_dropped['2010'].mean()
# Out:
# 6.918039215686274

# %%
df_copy['2010'].fillna(value=np.round(df['2010'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          cve_entidad  desc_entidad  cve_municipio  desc_municipio  \
# count          34926         34926          34926           34926
# size           34926         34926          34926           34926
# nunique           33            33            571            2321
#
#          id_indicador  indicador   1910   1921   1930   1940  ...   1960  \
# count           34926      34926     93     96     96     96  ...     96
# size            34926      34926  34926  34926  34926  34926  ...  34926
# nunique            17         17     86     92     93     91  ...     87
#
#           1970   1980   1990   1995   2000   2005   2010   2015  unidad_medida
# count       99     96     99     99     99     99  34926  34601          34926
# size     34926  34926  34926  34926  34926  34926  34926  34926          34926
# nunique     85     82     77     81     76     72    100  30682              1
#
# [3 rows x 21 columns]

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#        cve_entidad desc_entidad  cve_municipio               desc_municipio  \
# 7318            13      Hidalgo             60             Tenango de Doria
# 25168           21       Puebla            206                     Zacapala
# 13491           18      Nayarit             15           Santiago Ixcuintla
# 17046           20       Oaxaca            196  San Juan Evangelista Analco
# 1390             7      Chiapas             10            Bejucal de Ocampo
#
#        id_indicador                                          indicador  1910  \
# 7318     6207019067  Porcentaje de la poblacin de 6 a 11 aos que ...   NaN
# 25168    6200240368  Porcentaje de la poblacin de 15 aos y ms co...   NaN
# 13491    6207019031  Porcentaje de poblacin de 15 aos y ms con e...   NaN
# 17046    6207019029  Porcentaje de la poblacin de 15 a 24 aos que...   NaN
# 1390     6207019029  Porcentaje de la poblacin de 15 a 24 aos que...   NaN
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
# The lowest level of these is plt.subplot(), which creates a single subplot within a grid
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# axes are in a two-dimensional array, indexed by [row, col]
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
plt.hist(df_sample['cve_entidad'])
plt.xlabel('clave entidad')
plt.ylabel('Frequency')
plt.title('Frequency of clave entidad')
# Out:
# Text(0.5, 1.0, 'Frequency of clave entidad')

# %%
plt.boxplot(df_sample['cve_entidad'], showmeans=True, meanline=True)
plt.ylabel('cve_entidad')
plt.title('Box Plot of clave entidad')
# Out:
# Text(0.5, 1.0, 'Box Plot of clave entidad')
